# %%
#creating Node class
class Node:
    def __init__(self, data):
        self.data=data
        self.left=None
        self.right=None

# %%
#function to print nodes of the tree
def printTree(root):
    if root==None:
        return 
    print(root.data, end=":")
    if root.left != None:
        print('L:',root.left.data, end=" ")
    else:
        print('L:',None, end=" ")
    if root.right != None:
        print("R:",root.right.data)
    else:
        print('R:',None, end=" ")
    print()
    printTree(root.left)
    printTree(root.right)

# %%
#creating nodes manually 
root=Node(1)
l1=Node(2)
l2=Node(3)
l3=Node(4)
l4=Node(5)
l5=Node(6)

# %%
#linking nodes in tree manner
root.left=l1
root.right=l2
l1.left=l3
l1.right=l5
l2.right=l4

# %%
#printing nodes with their children
printTree(root)
# Out:
# 1:L: 2 R: 3
#
# 2:L: 4 R: 6
#
# 4:L: None R: None
# 6:L: None R: None
# 3:L: None R: 5
#
# 5:L: None R: None

# %%
#taking input in a tree
def treeInput():
    data=int(input())
    if data==-1:
        return 
    root=Node(data)
    left=treeInput()
    right=treeInput()
    root.left=left
    root.right=right
    return root

# %%
root=treeInput()
printTree(root)
# Out:
# 1
# 2
# 3
# -1
# -1
# 4
# 5
# -1
# -1
# -1
# 6
# -1
# 7
# -1
# 8
# -1
# 9
# -1
# -1
# 1:L: 2 R: 6
#
# 2:L: 3 R: 4
#
# 3:L: None R: None
# 4:L: 5 R: None
# 5:L: None R: None
# 6:L: None R: 7
#
# 7:L: None R: 8
#
# 8:L: None R: 9
#
# 9:L: None R: None

# %%
#counting no of nodes
def countNodes(root):
    if root==None:
        return 0
    leftSubTree=countNodes(root.left)
    rightSubTree=countNodes(root.right)
    return leftSubTree+rightSubTree+1

#taking input in a tree
def treeInput():
    data=int(input())
    if data==-1:
        return 
    root=Node(data)
    left=treeInput()
    right=treeInput()
    root.left=left
    root.right=right
    return root

root=treeInput()
print(countNodes(root))
# Out:
# 5
# 6
# 2
# -1
# -1
# 3
# -1
# 9
# -1
# -1
# 10
# -1
# -1
# 6

# %%
#sum of data of every node
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def sumOfAllNodes(root):
    if root==None:
        return 0
    data=root.data
    ldata=sumOfAllNodes(root.left)
    rdata=sumOfAllNodes(root.right)
    return data+ldata+rdata

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
print(sumOfAllNodes(root))
# Out:
# 1 2 3 -1 -1 -1 -1
# 6

# %%
#Pre Order traversal in a binary tree
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def preOrder(root):
    if root==None:
        return
    print(root.data, end=" ")
    preOrder(root.left)
    preOrder(root.right)

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
preOrder(root)
# Out:
# 8 3 10 1 6 -1 14 -1 -1 4 7 13 -1 -1 -1 -1 -1 -1 -1
# 8
# 3
# 1
# 6
# 4
# 7
# 10
# 14
# 13

# %%
#Post Order traversal in a binary tree
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def postOrder(root):
    if root==None:
        return 
    postOrder(root.left)
    postOrder(root.right)
    print(root.data, end=" ")

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
postOrder(root)
# Out:
# 1 2 4 -1 3 -1 5 -1 -1 6 7 -1 -1 -1 -1
# 3 2 6 7 5 4 1

# %%
#finding largest value node in binary tree
def largest(root):
    if root==None:
        return -1
    large=root.data
    llarge=largest(root.left)
    rlarge=largest(root.right)
    sublarge=llarge if llarge>rlarge else rlarge
    return large if large>sublarge else sublarge

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
print(largest(root))
# Out:
# 1 2 5 3 4 -1 -1 -1 -1 -1 -1
# 5

# %%
#counting no of nodes greater than X 
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def countNodesGreaterThanX(root, x):
    if root==None:
        return 0
    lcount=countNodesGreaterThanX(root.left, x)
    rcount=countNodesGreaterThanX(root.right, x)
    rootData=root.data
    if rootData>x:
        count=1
    else:
        count=0
    return lcount+rcount+count

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
x=int(input())
root = buildLevelTree(levelOrder)
print(countNodesGreaterThanX(root, x))
# Out:
# 8 3 10 1 6 -1 14 -1 -1 4 7 13 -1 -1 -1 -1 -1 -1 -1
# 8
# 3

# %%
#Height of binary tree
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def height(root):
    if root==None:
        return 0
    lheight=height(root.left)
    rheight=height(root.right)
    subHeight=max(lheight,rheight)
    return subHeight+1
    
def buildLevelTree():
    
    root = BinaryTreeNode(int(input()))
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = int(input())
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = int(input())
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
root = buildLevelTree()
print(height(root))
# Out:
# 1
# 2
# -1
# -1
# 3
# -1
# -1
# 3

# %%
#counting no of leaf nodes
def leafCount(root):
    if root==None:
        return 0
    if root.left==None and root.right==None:
        return 1
    leftCount=leafCount(root.left)
    rightCount=leafCount(root.right)
    return leftCount+rightCount
    
def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
print(leafCount(root))
# Out:
# 1 2 -1 -1 -1
# 1

# %%
#printing nodes at kth level --Approach 1
def nodesAtK(root,k):
    if root==None:
        return
    if k==0:
        print(root.data, end=' ')
        return
    nodesAtK(root.left,k-1)
    nodesAtK(root.right,k-1)
    
def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
level=int(input())
nodesAtK(root,level)
# Out:
# 1 2 3 -1 -1 4 5 -1 -1 -1 -1
# 2
# 4
# 5

# %%
#printing nodes at kth level --Approach 2
def nodeAtK(root, k, d=0):
    if root==None:
        return
    if k==d:
        print(root.data)
        return 
    nodeAtk(root.left, k, d+1)
    nodeAtK(root.right, k, d+1)
    
def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
level=int(input())
nodesAtK(root,level)
# Out:
# 1 -1 -1
# 0
# 1

# %%
#replacing value of nodes with its level
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def replaceWithDepth(root,level=0):
    if root==None:
        return 
    root.data=level
    replaceWithDepth(root.left,level+1)
    replaceWithDepth(root.right,level+1)
    
def inorder(root):
    if root is None:
        return
    inorder(root.left)
    print(root.data)
    inorder(root.right)

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
replaceWithDepth(root)
inorder(root)
# Out:
# 1 2 3 -1 -1 -1 -1
# 1
# 0
# 1

# %%
#checking if given node is present in the tree
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def isNodePresent(root, x):
    if root==None:
        return False
    if root.data==x:
        return True
    l=isNodePresent(root.left, x)
    r=isNodePresent(root.right, x)
    if l==True or r==True:
        return True
    else:
        return False


def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
x=int(input())
present=isNodePresent(root, x)
if present==True:
    print('true')
else:
    print('false')
# Out:
# 8 3 10 1 6 -1 14 -1 -1 4 7 13 -1 -1 -1 -1 -1 -1 -1
# 100
# false

# %%
#printing nodes without sibling
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def nodesWithoutSibling(root):
    if root==None:
        return 
    if root.left==None and root.right!=None:
        nodesWithoutSibling(root.right)
        print(root.right.data)
        return
    if root.left!=None and root.right==None:
        nodesWithoutSibling(root.left)
        print(root.left.data)
        return
    nodesWithoutSibling(root.left)
    nodesWithoutSibling(root.right)

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
nodesWithoutSibling(root)
# Out:
# 1 2 3 -1 4 5 -1 -1 -1 6 -1 -1 -1
# 4
# 6
# 5

# %%
#making mirror of binary tree
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def mirrorBinaryTree(root):
    if root==None:
        return 
    if root.left==None and root.right==None:
        return 
    root.left, root.right=root.right, root.left
    mirrorBinaryTree(root.left)
    mirrorBinaryTree(root.right)
        

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root


def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
mirrorBinaryTree(root)
printLevelATNewLine(root)
# Out:
# 5 10 6 2 3 -1 -1 -1 -1 -1 9 -1 -1
# 5
# 6 10
# 3 2
# 9

# %%
#removing all the leaf nodes
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def removeLeaf(root):
    if root==None:
        return 
    if root.left==None and root.right==None:
        return
    root.left=removeLeaf(root.left)
    root.right=removeLeaf(root.right)
    return root

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return 
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
removeLeaf(root)
printLevelATNewLine(root)
# Out:
# 1 2 3 4 5 -1 -1 -1 -1 6 7 -1 -1 -1 -1
# 1
# 2
# 5

# %%
#check if binary tree is balanced or not. O(n^2) in worst case otherwise O(nlogn)
def height(root):
    if root==None:
        return 0
    return 1+height(root.left)+height(root.right)
    
def isBalanced(root):
    if root==None:
        return True
    lheight=height(root.left)
    rheight=height(root.right)
    if rheight-lheight>1 or lheight-rheight>1:
        return False
    isLeftBalanced=isBalanced(root.left)
    isRightBalanced=isBalanced(root.right)
    if isLeftBalanced==True and isRightBalanced==True:
        return True
    else:
        return False
    
def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
print(isBalanced(root))
# Out:
# 1 2 -1 4 -1 -1 -1 -1
# False

# %%
#check if binary tree is balanced or not. O(n) optimized solution
def height(root):
    if root==None:
        return 0
    return 1+height(root.left)+height(root.right)
    
def isBalanced(root):
    if root==None:
        return 0,True
    lh,isLeftBalance=isBalanced(root.left)
    rh,isRightBalance=isBalanced(root.right)
    height=1+max(lh, rh)
    if lh-rh>1 or rh-lh>1:
        return height, False
    if isLeftBalance==True and isRightBalance==True:
        return height, True
    else:
        return height, False
    
def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
print(isBalanced(root))
# Out:
# 1 2 -1 4 -1 -1 -1 -1
# (3, False)

# %%
#finding diameter of binary tree
'''Diameter of binary tree is the distance between two farthest node'''
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def diameter(root):
    if root==None:
        return 0,0
    lh,ld=diameter(root.left)
    rh,rd=diameter(root.right)
    height=max(lh, rh)+1
    if lh+rh<ld:
        return  height ,ld
    if lh+rh<rd:
        return height, rd
    else:
        return height, lh+rh

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
h,d=diameter(root)
print(d)
# Out:
# 1 2 4 3 -1 -1 -1 -1 -1
# 3

# %%
#Taking level wise tree input
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
def takingLevelWiseInput():
    import queue
    print("enter root")
    root=int(input())
    if root==-1:
        return 
    rootData=BinaryTreeNode(root)
    q=queue.Queue()
    q.put(rootData)
    while q.empty()==False:
        currData=q.get()
        print("enter left child of",currData.data)
        leftChild=int(input())
        if leftChild != -1:
            leftNode=BinaryTreeNode(leftChild)
            currData.left=leftNode
            q.put(leftNode)
            
        print("enter right child of",currData.data)
        rightChild=int(input())
        if rightChild != -1:
            rightNode=BinaryTreeNode(rightChild)
            currData.right=rightNode
            q.put(rightNode)
            
    return rootData


root=takingLevelWiseInput()
printTree(root)
# Out:
# enter root
# 1
# enter left child of 1
# 2
# enter right child of 1
# 3
# enter left child of 2
# -1
# enter right child of 2
# -1
# enter left child of 3
# -1
# enter right child of 3
# -1
# 1:L: 2 R: 3
#
# 2:L: None R: None
# 3:L: None R: None

# %%
#printing tree level wise
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def printLevelWise(root):
    q=queue.Queue()
    q.put(root)
    while q.empty()==False:
        currNode=q.get()
        if currNode.left is None and currNode.right is None:
            print(currNode.data,':','L',':','-1',',','R',':','-1',sep='')
        elif currNode.left is None:
            print(currNode.data,':','L',':','-1',',','R',':',currNode.right.data,sep='')
            q.put(currNode.right)
        elif currNode.right is None:
            print(currNode.data,':','L',':',currNode.left.data,',','R',':','-1',sep='')
            q.put(currNode.left)
        else:
            print(currNode.data,':','L',':',currNode.left.data,',','R',':',currNode.right.data,sep='')
            q.put(currNode.left)
            q.put(currNode.right)
    #print("while loop not working")
        

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    
    return root

# Main 
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
printLevelWise(root)
# Out:
# 5 6 10 2 3 -1 -1 -1 -1 -1 9 -1 -1
# 5:L:6,R:10
# 6:L:2,R:3
# 10:L:-1,R:-1
# 2:L:-1,R:-1
# 3:L:-1,R:9
# 9:L:-1,R:-1

# %%
#constructing tree using inorder and preorder
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def buildTreePreOrder(preorder, inorder):
    if len(preorder)==0 or len(inorder)==0:
        return 
    rootData=preorder[0]
    root=BinaryTreeNode(rootData)
    for i in range(len(inorder)):
        if inorder[i]==rootData:
            rootIndexInorder=i
            break
    lenLeftSubTree=rootIndexInorder
    leftInorder=inorder[0:lenLeftSubTree]
    rightInorder=inorder[lenLeftSubTree+1:]
    leftPreorder=preorder[1:lenLeftSubTree+1]
    rightPreorder=preorder[lenLeftSubTree+1:]
    leftSubTree=buildTreePreOrder(leftPreorder, leftInorder)
    rightSubTree=buildTreePreOrder(rightPreorder, rightInorder)
    root.left=leftSubTree
    root.right=rightSubTree
    return root

def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
n=int(input())
preorder = [int(i) for i in input().strip().split()]
inorder = [int(i) for i in input().strip().split()]
root = buildTreePreOrder(preorder, inorder)
printLevelATNewLine(root)
# Out:
# 12
# 1 2 3 4 15 5 6 7 8 10 9 12
# 4 15 3 2 5 1 6 10 8 7 9 12
# 1
# 2 6
# 3 5 7
# 4 8 9
# 15 10 12

# %%
#constructing tree using inorder and postorder
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def buildTreePostOrder(postorder, inorder):
    if len(postorder)==0 or len(inorder)==0:
        return 
    rootData=postorder[-1]
    root=BinaryTreeNode(rootData)
    for i in range(len(inorder)):
        if inorder[i]==rootData:
            rootIndexInorder=i
            break
    lenLeftSubTree=rootIndexInorder
    leftInorder=inorder[0:lenLeftSubTree]
    rightInorder=inorder[lenLeftSubTree+1:]
    leftPostorder=postorder[0:lenLeftSubTree]
    rightPostorder=postorder[lenLeftSubTree:-1]
    leftSubTree=buildTreePostOrder(leftPostorder, leftInorder)
    rightSubTree=buildTreePostOrder(rightPostorder, rightInorder)
    root.left=leftSubTree
    root.right=rightSubTree
    return root

def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
n=int(input())
postOrder = [int(i) for i in input().strip().split()]
inorder = [int(i) for i in input().strip().split()]
root = buildTreePostOrder(postOrder, inorder)
printLevelATNewLine(root)
# Out:
# 8
# 8 4 5 2 6 7 3 1
# 4 8 2 5 1 6 3 7
# 1
# 2 3
# 4 5 6 7
# 8

# %%
#create and insert duplicate nodes in left of root
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def insertDuplicateNode(root):
    if root==None:
        return 
    duplicate=root.data
    duplicateNode=BinaryTreeNode(duplicate)
    leftChild=root.left
    root.left=duplicateNode
    duplicateNode.left=leftChild
    insertDuplicateNode(duplicateNode.left)
    insertDuplicateNode(root.right)

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
insertDuplicateNode(root)
printLevelATNewLine(root)
# Out:
# 8 5 10 2 6 -1 -1 -1 -1 -1 7 -1 -1
# 8
# 8 10
# 5 10
# 5 6
# 2 6 7
# 2 7

# %%
#Finding minimum and maximum data in binary tree
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

INT_MIN = -2147483648
INT_MAX = 2147483647
# Problem ID 1567, Find the minimum and maximum value
def minMax(root):
    if root==None:
        return INT_MAX, INT_MIN
    leftMin, leftMax=minMax(root.left)
    rightMin, rightMax=minMax(root.right)
    maximum=max(leftMax, rightMax, root.data)
    minimum=min(leftMin, rightMin, root.data)
    return minimum, maximum

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
minimum, maximum = minMax(root)
print(maximum, minimum)
# Out:
# 8 3 10 1 6 -1 14 -1 -1 4 7 13 -1 -1 -1 -1 -1 -1 -1
# 14 1

# %%
#Printing tree levelwise
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def printLevelATNewLine(root):
    q=queue.Queue()
    q.put(root)
    q.put(None)#None will indicate end of level
    while q.empty()==False:
        current=q.get()
        if current is None:
            print()
            if q.empty()==False:
                q.put(None)
        else:
            print(current.data, end=' ')
            if current.left:
                q.put(current.left)
            if current.right:
                q.put(current.right)
                

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
#n=int(input())
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
printLevelATNewLine(root)
# Out:
# 5 6 10 2 3 -1 -1 -1 -1 -1 9 -1 -1
# 5
# 6 10
# 2 3
# 9

# %%
#printing path from root to leaf having sum=k
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def rootToLeafPathsSumToK(root, k, lst):
    if root is None:
        return
    if root.left is None and root.right is None:
        if root.data==k:
            lst.append(root.data)
            print(*lst)
            lst.pop()
            return
    lst.append(root.data)
    rootToLeafPathsSumToK(root.left, k-root.data, lst)
    rootToLeafPathsSumToK(root.right, k-root.data, lst)
    lst.pop()

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
k=int(input())
rootToLeafPathsSumToK(root, k, [])
# Out:
# 5 6 7 2 3 -1 1 -1 -1 -1 9 -1 -1 -1 -1
# 13
# 5 6 2
# 5 7 1

# %%
#print nodes at distance k form the given node.
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def printAtDepthK(root,k):
    if root is None:
        return
    if k==0:
        print(root.data)
        return
    printAtDepthK(root.left,k-1)
    printAtDepthK(root.right,k-1)

def printNodesK(root,element,k):
    if root is None:
        return -1
    if root.data==element:
        printAtDepthK(root,k)
        return 0
    lD=printNodesK(root.left,element,k)
    if lD!=-1:
        distanceLeft=lD+1
        if k==distanceLeft:
            print(root.data)
            return distanceLeft
        else:
            rightDepth=k-distanceLeft-1
            printAtDepthK(root.right,rightDepth)
            return distanceLeft
    rD=printNodesK(root.right,element,k)
    if rD != -1:
        distanceRight = rD + 1
        if k == distanceRight:
            print(root.data)
            return distanceRight
        else:
            leftDepth = k - distanceRight - 1
            printAtDepthK(root.left, leftDepth)
            return distanceRight
    if lD==-1 and rD==-1:
        return -1


def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
element=int(input())
k=int(input())
printNodesK(root,element,k)

# %%
#printing node to root path if node found in the tree
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def nodeToRoot(root, k):
    if root==None:
        return 
    if root.data==k:
        l=[]
        l.append(root.data)
        return l
    leftSubTree=nodeToRoot(root.left, k)
    if leftSubTree:
        leftSubTree.append(root.data)
        return leftSubTree
    rightSubTree=nodeToRoot(root.right, k)
    if rightSubTree:
        rightSubTree.append(root.data)
        return rightSubTree
    return
        
def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
k=int(input())
root = buildLevelTree(levelOrder)
l=nodeToRoot(root, k)
for i in l:
    print(i)
# Out:
# 8 5 10 2 6 -1 -1 -1 -1 -1 7 -1 -1
# 2
# 2
# 5
# 8

# %%
mport queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def printAtDepthK(root,k):
    if root is None:
        return
    if k==0:
        print(root.data)
        return
    printAtDepthK(root.left,k-1)
    printAtDepthK(root.right,k-1)

def printNodesK(root,element,k):
    if root is None:
        return -1
    if root.data==element:
        printAtDepthK(root,k)
        return 0
    lD=printNodesK(root.left,element,k)
    if lD!=-1:
        distanceLeft=lD+1
        if k==distanceLeft:
            print(root.data)
            return distanceLeft
        else:
            rightDepth=k-distanceLeft-1
            printAtDepthK(root.right,rightDepth)
            return distanceLeft
    rD=printNodesK(root.right,element,k)
    if rD != -1:
        distanceRight = rD + 1
        if k == distanceRight:
            print(root.data)
            return distanceRight
        else:
            leftDepth = k - distanceRight - 1
            printAtDepthK(root.left, leftDepth)
            return distanceRight
    if lD==-1 and rD==-1:
        return -1


def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
element=int(input())
k=int(input())
printNodesK(root,element,k)
