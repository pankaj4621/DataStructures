# %%
#implementation of min priority queue
class PriorityQueueNode:
    def __init__(self,ele,priority):
        self.ele = ele
        self.priority = priority
        
class PriorityQueue:
    def __init__(self):
        self.pq = []
    
    def isEmpty(self):
        return self.getSize() == 0
    
    def getSize(self):
        return len(self.pq)

    def getMin(self):
        if self.isEmpty():
            return None
        return self.pq[0].ele
    
    def __percolateUp(self):
        childIndex = self.getSize() - 1
        while childIndex > 0:
            parentIndex = (childIndex-1)//2
            
            if self.pq[parentIndex].priority > self.pq[childIndex].priority:
                self.pq[parentIndex],self.pq[childIndex] = self.pq[childIndex],self.pq[parentIndex]
                childIndex = parentIndex
            else:
                break
            
    def insert(self,ele,priority):
        pqNode = PriorityQueueNode(ele,priority)
        self.pq.append(pqNode)
        self.__percolateUp()
        
    def __percolateDown(self):
        parentIndex=0
        while 2*parentIndex+1 <self.getSize() or 2*parentIndex+2<self.getSize():
            lChild=2*parentIndex+1
            rChild=2*parentIndex+2
            if lChild>=self.getSize():
                min=rChild
            elif rChild>=self.getSize():
                min=lChild
            else:
                min=lChild if self.pq[lChild].priority<self.pq[rChild].priority else rChild
            if self.pq[min].priority<self.pq[parentIndex].priority:
                self.pq[min],self.pq[parentIndex]=self.pq[parentIndex],self.pq[min]
                parentIndex=min
            else:
                break
                
    def removeMin(self):
        removed=self.pq[0].ele
        self.pq[0]=self.pq[-1]
        self.pq.pop()
        self.__percolateDown()
        return removed
        
myPq = PriorityQueue()
curr_input = [int(ele) for ele in input().split()]
choice = curr_input[0]
i=1
while choice != -1:
    if choice == 1:
        element = curr_input[i]
        i+=1
        myPq.insert(element,element)
    elif choice == 2:
        print(myPq.getMin())
    elif choice == 3:
        print(myPq.removeMin())
    elif choice == 4:
        print(myPq.getSize())
    elif choice == 5:
        if myPq.isEmpty():
            print('true')
        else:
            print('false')
        break
    else:
        pass
    choice = curr_input[i]
    i+=1
# Out:
# 1 3 1 4 1 63 1 21 1 9 2 3 1 7 3 4 5 3 3 -1
# 3
# 3
# 4
# 4
# false

# %%
#implementation of max priority queue
class PriorityQueueNode:
    def __init__(self,ele,priority):
        self.ele = ele
        self.priority = priority
        
class PriorityQueue:
    def __init__(self):
        self.pq = []
    
    def isEmpty(self):
        return self.getSize() == 0
    
    def getSize(self):
        return len(self.pq)

    def getMin(self):
        if self.isEmpty():
            return None
        return self.pq[0].ele
    
    def __percolateUp(self):
        childIndex = self.getSize() - 1
        while childIndex > 0:
            parentIndex = (childIndex-1)//2
            
            if self.pq[parentIndex].priority > self.pq[childIndex].priority:
                self.pq[parentIndex],self.pq[childIndex] = self.pq[childIndex],self.pq[parentIndex]
                childIndex = parentIndex
            else:
                break
            
    def insert(self,ele,priority):
        pqNode = PriorityQueueNode(ele,priority)
        self.pq.append(pqNode)
        self.__percolateUp()
        
    def __percolateDown(self):
        parentIndex=0
        while 2*parentIndex+1 <self.getSize() or 2*parentIndex+2<self.getSize():
            lChild=2*parentIndex+1
            rChild=2*parentIndex+2
            if lChild>=self.getSize():
                min=rChild
            elif rChild>=self.getSize():
                min=lChild
            else:
                min=lChild if self.pq[lChild].priority<self.pq[rChild].priority else rChild
            if self.pq[min].priority<self.pq[parentIndex].priority:
                self.pq[min],self.pq[parentIndex]=self.pq[parentIndex],self.pq[min]
                parentIndex=min
            else:
                break
                
    def removeMin(self):
        removed=self.pq[0].ele
        self.pq[0]=self.pq[-1]
        self.pq.pop()
        self.__percolateDown()
        return removed
        
myPq = PriorityQueue()
curr_input = [int(ele) for ele in input().split()]
choice = curr_input[0]
i=1
while choice != -1:
    if choice == 1:
        element = curr_input[i]
        i+=1
        myPq.insert(element,element)
    elif choice == 2:
        print(myPq.getMin())
    elif choice == 3:
        print(myPq.removeMin())
    elif choice == 4:
        print(myPq.getSize())
    elif choice == 5:
        if myPq.isEmpty():
            print('true')
        else:
            print('false')
        break
    else:
        pass
    choice = curr_input[i]
    i+=1
# Out:
# 1 3 1 4 1 63 1 21 1 9 2 3 1 7 2 2 2 3 3 3 -1
# 3
# 3
# 4
# 4
# 4
# 4
# 7
# 9

# %%
class PriorityClassNode:
    def __init__(self, value, priority):
        self.value=value
        self.priority=priority

class PriorityQueue:
    def __init__(self):
        self.pq=[]
        
    def isEmpty(self):
        return self.getSize()==0
    
    def getSize(self):
        return len(self.pq)

    def getMax(self):
        return self.pq[0].value
    
    def __percolateUp(self):
        childIndex=self.getSize()-1
        while childIndex>0:
            parentIndex=(childIndex-1)//2
            if self.pq[parentIndex].priority<self.pq[childIndex].priority:
                self.pq[parentIndex], self.pq[childIndex]=self.pq[childIndex], self.pq[parentIndex]
                childIndex=parentIndex
            else:
                break
    
    def insert(self,value,priority):
        pqNode=PriorityClassNode(value, priority)
        self.pq.append(pqNode)
        self.__percolateUp()
        
    def __percolateDown(self):
        parentIndex=0
        lChild=2*parentIndex+1
        rChild=2*parentIndex+2
        while lChild<self.getSize():
            max=parentIndex
            if self.pq[parentIndex].priority<self.pq[lChild].priority:
                max=lChild
            if rChild<self.getSize() and self.pq[rChild].priority>self.pq[max].priority:
                max=rChild
            if max==parentIndex:
                break
            else:
                self.pq[parentIndex],self.pq[max]=self.pq[max], self.pq[parentIndex]
                parentIndex=max
                lChild=2*parentIndex+1
                rChild=2*parentIndex+2
        
    def removeMax(self):
        removed=self.pq[0].value
        self.pq[0]=self.pq[-1]
        self.pq.pop()
        self.__percolateDown()
        return removed
        
myPq = PriorityQueue()
curr_input = [int(ele) for ele in input().split()]
choice = curr_input[0]
i=1
while choice != -1:
    if choice == 1:
        element = curr_input[i]
        i+=1
        myPq.insert(element,element)
    elif choice == 2:
        print(myPq.getMax())
    elif choice == 3:
        print(myPq.removeMax())
    elif choice == 4:
        print(myPq.getSize())
    elif choice == 5:
        if myPq.isEmpty():
            print('true')
        else:
            print('false')
        break
    else:
        pass
    choice = curr_input[i]
    i+=1
# Out:
# 1 3 1 4 1 63 1 21 1 9 2 3 1 7 2 3 2 -1
# 63
# 63
# 21
# 21
# 9

# %%
#implementation of heap sort -- Optimised approach (building heap 0(n))
def downHeapify(arr, i, n):
    parentIndex=i
    lChildIndex=2*i+1
    rChildIndex=2*i+2
    minIndex=parentIndex
    while lChildIndex<n:
        if arr[parentIndex]>arr[lChildIndex]:
            minIndex=lChildIndex
        if rChildIndex<n and arr[rChildIndex]<arr[minIndex]:
            minIndex=rChildIndex
        if minIndex==parentIndex:
            return 
        arr[parentIndex],arr[minIndex]=arr[minIndex],arr[parentIndex]
        parentIndex=minIndex
        lChildIndex=2*parentIndex+1
        rChildIndex=2*parentIndex+2
    return
            
def HeapSort(arr):
    #step1 building heap in O(n/2logn) i.e O(n)
    n=len(arr)
    for i in range(n//2-1, -1, -1):
        downHeapify(arr, i, n)
    #remove elements from heap one by one and place them at theit correct position
    for i in range(n-1,0,-1):
        arr[i],arr[0]=arr[0],arr[i]
        downHeapify(arr, 0, i)
    return arr

arr=[int(i) for i in input().split()]
arr=HeapSort(arr)
print(*arr)
# Out:
# 995 379 207 451 721 872 861 75 866 671 998 124 313 490 799 652 545 583 328 639 534 439 257 788 1000 344 836 596 624 639 768 219 605 608 424 882 958 513 273 699 73 237 484 807 339 364 412 672 121 291 83 262 940 150 845 537 508 903 72 376 164 945 193 625 342 973 314 409 936 652 426 261 802 844 499 877 201 756 779 513 666 400 250 143 648 178 534 490 298 243 471 959 924 518 241 319 972 900 157 705 868 253 222 139 701 207 102 304 519 684 427 751 941 324 242 64 937 670 983 767 834 33 558 915 87 480 14 380 870 259 767 808 320 281 570 126 126 991 255 233 213 84 734 231 465 12 951 119 790 193 252 425 345 135 108 591 395 451 270 331 133 859 190 325 731 849 988 789 66 620 330 495 840 281 342 725 255 69 62 538 44 510 28 441 377 48 281 242 115 637 453 429 949 193 644 876 183 627 447 74 325 334 867 368 175 698 821 861 820 127 622 760 783 610 94 945 596 585 995 426 240 170 983 211 206 439 709 800 423 492 475 163 943 504 572 596 46 825 576 283 397 470 856 759 983 985 58 697 839 810 561 634 953 702 7
# ...

# %%
#implementation of heap sort (---building heap O(nlogn))
def downHeapify(arr, i, n):
    parentIndex=i
    lChildIndex=2*i+1
    rChildIndex=2*i+2
    minIndex=parentIndex
    while lChildIndex<n:
        if arr[parentIndex]>arr[lChildIndex]:
            minIndex=lChildIndex
        if rChildIndex<n and arr[rChildIndex]<arr[minIndex]:
            minIndex=rChildIndex
        if minIndex==parentIndex:
            downHeapify(arr, 2*parentIndex+1, n)
            downHeapify(arr, 2*parentIndex+2, n)
            return
        
        arr[parentIndex],arr[minIndex]=arr[minIndex],arr[parentIndex]
        parentIndex=minIndex
        lChildIndex=2*parentIndex+1
        rChildIndex=2*parentIndex+2
    return
            
def HeapSort(arr):
    #step1 building heap in O(nlogn)
    n=len(arr)
    for i in range(1,n+1):
        downHeapify(arr, 0, i)
    #remove elements from heap one by one and place them at theit correct position
    for i in range(n-1,0,-1):
        arr[i],arr[0]=arr[0],arr[i]
        downHeapify(arr, 0, i)
    return arr

arr=[int(i) for i in input().split()]
arr=HeapSort(arr)
print(*arr)
# Out:
# 995 379 207 451 721 872 861 75 866 671 998 124 313 490 799 652 545 583 328 639 534 439 257 788 1000 344 836 596 624 639 768 219 605 608 424 882 958 513 273 699 73 237 484 807 339 364 412 672 121 291 83 262 940 150 845 537 508 903 72 376 164 945 193 625 342 973 314 409 936 652 426 261 802 844 499 877 201 756 779 513 666 400 250 143 648 178 534 490 298 243 471 959 924 518 241 319 972 900 157 705 868 253 222 139 701 207 102 304 519 684 427 751 941 324 242 64 937 670 983 767 834 33 558 915 87 480 14 380 870 259 767 808 320 281 570 126 126 991 255 233 213 84 734 231 465 12 951 119 790 193 252 425 345 135 108 591 395 451 270 331 133 859 190 325 731 849 988 789 66 620 330 495 840 281 342 725 255 69 62 538 44 510 28 441 377 48 281 242 115 637 453 429 949 193 644 876 183 627 447 74 325 334 867 368 175 698 821 861 820 127 622 760 783 610 94 945 596 585 995 426 240 170 983 211 206 439 709 800 423 492 475 163 943 504 572 596 46 825 576 283 397 470 856 759 983 985 58 697 839 810 561 634 953 702 7
# ...

# %%
#print k smallest numbers  O(nlogk)
import heapq
def kSmallest(lst, k):
    li=lst[0:k]
    heapq._heapify_max(li)  #building max order heap
    for i in range(k,len(lst)):
        top=li[0]
        if lst[i]<top:
            heapq._heapreplace_max(li, lst[i])  #replacing top of heap with lst[i]
    return li

# Main
n=int(input())
lst=list(int(i) for i in input().strip().split(' '))
k=int(input())
ans=kSmallest(lst, k)
print(*ans)
# Out:
# 13
# 2 12 9 16 10 5 3 20 25 11 1 8 6
# 4
# 5 2 3 1

# %%
#print k largest numbers  O(nlogk)
import heapq
def kLargest(lst, k):
    li=lst[0:k]
    heapq.heapify(li)  #building min order heap
    for i in range(k,len(lst)):
        top=li[0]
        if lst[i]>top:
            heapq.heapreplace(li, lst[i]) #replacing top of heap with lst[i]
    return li

# Main
n=int(input())
lst=list(int(i) for i in input().strip().split(' '))
k=int(input())
ans=kLargest(lst, k)
print(*ans)
# Out:
# 13
# 2 12 9 16 10 5 3 20 25 11 1 8 6
# 4
# 12 16 20 25

# %%
#check if given array represent max heap or not
import heapq
def checkMaxHeap(lst):
    p=0
    l=2*p+1
    r=2*p+2
    while l<len(lst):
        if lst[p]<lst[l]:
            return False
        elif r<len(lst) and lst[p]<lst[r]:
            return False
        p=p+1
        l=2*p+1
        r=2*p+2
    return True

# Main Code
n=int(input())
lst=list(int(i) for i in input().strip().split(' '))
print('true') if checkMaxHeap(lst) else print('false')
# Out:
# 20
# 94032 91513 83822 86096 77055 65181 59534 63999 84904 35945 21525 44579 45064 36554 51655 9737 548 53228 26519 17196
# true

# %%
#Kth largest element
import heapq
def kthLargest(lst, k):
    i=0
    ans=0
    heapq._heapify_max(lst)
    while i<k:
        ans=heapq._heappop_max(lst)
        i=i+1
    return ans

# Main Code
n=int(input())
lst=list(int(i) for i in input().strip().split(' '))
k=int(input())
ans=kthLargest(lst, k)
print(ans)
# Out:
# 8
# 2 6 10 11 13 4 1 20
# 4
# 10

# %%
from queue import Queue
import heapq

def ticket(arr, k):
    count=0
    d={}           
    q=Queue()
    for i in range(0, len(arr)):
        q.put(i)
        d[i]=arr[i]
        
    heapq._heapify_max(arr)
    pq=arr
    while q.empty()==False:
        curr=q.get()
        if curr==k:
            if d[curr]== pq[0]:
                count+=1
                return count
            q.put(curr)
        else:
            if d[curr]==pq[0]:
                count+=1
                heapq._heappop_max(pq)
            else:
                q.put(curr)
                
    return count

#main
n=int(input())
arr = [int(i) for i in input().split()]
k=int(input())
print(ticket(arr, k))
# Out:
# 5
# 2 3 2 2 4
# 3
# 4

# %%
from queue import Queue
import heapq

def ticket(arr, k):
    count=0
    d={}   
    q=Queue()
    for i in range(0, len(arr)):
        q.put(i)
        d[i]=arr[i]
        
    #heapq._heapify_max(arr)
    
    pq=sorted(arr, reverse=True) 
    
    while q.empty()==False:
        curr=q.get()
        if curr==k:
            if d[curr]== pq[0]:
                count+=1
                return count
            q.put(curr)
        else:
            if d[curr]==pq[0]:
                count+=1
                #heapq._heappop_max(pq)
                pq.pop(0)
            else:
                q.put(curr)
                
    return count

#main
n=int(input())
arr = [int(i) for i in input().split()]
k=int(input())
print(ticket(arr, k))
# Out:
# 5
# 2 3 2 2 4
# 3
# 4

# %%
import heapq
def ticket(arr,k,count):
    Priority=arr[k]
    heapq._heapify_max(arr)
    time=0
    while True:
        temp=heapq._heappop_max(arr)
        time+=1
        if temp==Priority:
            count-=1
            if count<=0:
            	return time
            
n = int(input())                
li = [int(x) for x in input().split()]
k = int(input())
count=0
for i in range(k):
    if li[k]==li[i]:
        count+=1
print(ticket(li,k,count))
