# %%
#defining tree node for generic trees
class TreeNode:
    def __init__(self, data):
        self.data=data
        self.children=[]

# %%
#creating nodes manually
t1=TreeNode(1)
t2=TreeNode(2)
t3=TreeNode(3)
t4=TreeNode(4)
t5=TreeNode(5)
t6=TreeNode(6)
t7=TreeNode(7)
t8=TreeNode(8)
t9=TreeNode(9)
t10=TreeNode(10)

# %%
#connecting nodes of t1
t1.children.append(t2)
t1.children.append(t3)
t1.children.append(t4)
t1.children.append(t5)

#connecting nodes of t3
t3.children.append(t6)
t3.children.append(t7)

#connecting nodes of t5
t5.children.append(t8)
t5.children.append(t9)
t5.children.append(t10)

# %%
#printing node's data of the tree in pre order
def printTree(root):
    if root==None:
        return
    print(root.data, end=' ')
    for child in root.children:
        printTree(child)
        
printTree(t1)
# Out:
# 1 2 3 6 7 4 5 8 9 10 2 3 6 7 4 5 8 9 10

# %%
#printing node's data of the tree detailed in pre order
def printTreeDetailed(root):
    if root==None:
        return
    print(root.data,':', end=' ')
    for i in root.children:
        print(i.data, end=' ')
    print()
    for child in root.children:
        printTreeDetailed(child)

# %%
#taking tree input
def treeInput():
    rootData=int(input('enter root data: '))
    if rootData==None:
        return None
    root=TreeNode(rootData)
    print('enter no of children for', root.data)
    noChildren=int(input())
    for i in range(noChildren):
        child=treeInput()
        root.children.append(child)
    return root

# %%
root=treeInput()    
printTreeDetailed(root)

# %%
# defining no of nodes in the generic tree
def noOfNodes(root):
    if root==None:
        return
    count=1
    for child in root.children:
        count=count+noOfNodes(child)
    return count

# %%
#printing no of nodes in the generic tree
root=treeInput()    
print(noOfNodes(root))
# Out:
# enter root data: 1
# enter no of children for 1
# 3
# enter root data: 2
# enter no of children for 2
# 0
# enter root data: 3
# enter no of children for 3
# 2
# enter root data: 5
# enter no of children for 5
# 0
# enter root data: 6
# enter no of children for 6
# 0
# enter root data: 4
# enter no of children for 4
# 0
# 6

# %%
#printing sum of data of all the nodes of the tree
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
    def __str__(self):
        return str(self.data)

def sumofNodes(tree):
    sum=tree.data
    for child in tree.children:
        sum=sum+sumofNodes(child)
    return sum

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
print(sumofNodes(tree))
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 190

# %%
#finding node with maximum data in the tree
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
    def __str__(self):
        return str(self.data)

def maxDataNode(tree):
    if tree==None:
        return 
    maximum=tree.data
    for child in tree.children:
        childMax=maxDataNode(child)
        maximum=max(maximum, childMax)
    return maximum

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
print(maxDataNode(tree))
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 50

# %%
#finding height of the tree
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
    def __str__(self):
        return str(self.data)

def heightOfTree(tree):
    if tree==None:
        return 
    max=0
    for child in tree.children:
        height=heightOfTree(child)
        if height>max:
            max=height
    return max+1

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
print(heightOfTree(tree))
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 3

# %%
#taking tree input levelwise
import queue

class TreeNode:
    def __init__(self, data):
        self.data=data
        self.children=[]
        
def treeInputLevelwise():
    rootData=int(input('enter the root: '))
    if rootData==-1:
        return 
    root=TreeNode(rootData)
    q=queue.Queue()
    q.put(root)
    while q.empty()==False:
        current=q.get()
        print('enter no of children for',current.data)
        noofChildren=int(input())
        for i in range(noofChildren):
            print('enter',i+1, 'child of ',current.data)
            childData=int(input())
            child=TreeNode(childData)
            current.children.append(child)
            q.put(child)
    return root        

def printLevelWiseTree(tree):
    if tree==None:
        return
    print(tree.data, end=':')
    for i in range(0, len(tree.children)):
        if i==len(tree.children)-1:
            print(tree.children[i].data)
        print(tree.children[i].data, end=',')
    print()
    for child in tree.children:
        printLevelWiseTree(child)

# %%
root=treeInputLevelwise()
printLevelWiseTree(root)
# Out:
# enter the root: 5
# enter no of children for 5
# 3
# enter 1 child of  5
# 6
# enter 2 child of  5
# 7
# enter 3 child of  5
# 8
# enter no of children for 6
# 0
# enter no of children for 7
# 2
# enter 1 child of  7
# 9
# enter 2 child of  7
# 10
# enter no of children for 8
# 0
# enter no of children for 9
# 0
# enter no of children for 10
# 0
# 5:6,7,8
# 8,
# 6:
# 7:9,10
# 10,
# 9:
# 10:
# 8:

# %%
#printing Tree levelWise
import queue
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
    def __str__(self):
        return str(self.data)
    
def printLevelWiseTree(root):
    if root==None:
        return
    q=queue.Queue()
    q.put(root)
    while q.empty()==False:
        curr=q.get()
        print(curr.data, end=':')
        for child in curr.children:
            if curr.children.index(child)==len(curr.children)-1:
                print(child.data, end='')
                q.put(child)
            else:
                print(child.data, end=',')
                q.put(child)
        print()


def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
printLevelWiseTree(tree)
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 10:20,30,40
# 20:40,50
# 30:
# 40:
# 40:
# 50:

# %%
#check if the given tree contains the node x or not
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
    def __str__(self):
        return str(self.data)

def containsX(tree, x):
    if tree==None:
        return False
    if tree.data==x:
        return True
    subTree=False
    for child in tree.children:
        subTree=containsX(child, x)
        if subTree==True:
            break
    return subTree

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
x=int(input())
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
if containsX(tree,x):
    print('true')
else:
    print('false')
# Out:
# 4
# 10 3 20 30 40 2 40 50 0 0 0 0
# false

# %%
#count no of leaf node in the tree
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
    def __str__(self):
        return str(self.data)

def leafNodeCount(tree):
    if tree==None:
        return 0
    if len(tree.children) == 0:
        return 1
    nodeCount=0
    for child in tree.children:
        nodeCount=nodeCount+leafNodeCount(child)
    return nodeCount   
        
def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
print(leafNodeCount(tree))
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 4

# %%
#print node with maximum sum of its children and node itself
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []

def maxSumNode(tree):
    if tree==None:
        return 
    node=tree
    maxSum=tree.data
    for child in  tree.children:
        maxSum=maxSum+child.data
    for child in tree.children:
        childMaxSum,childNode=maxSumNode(child)
        if childMaxSum>maxSum:
            maxSum=childMaxSum
            node=childNode
    return maxSum, node

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
tempsum, temp = maxSumNode(tree)
print(temp.data)
# Out:
# 5 3 1 2 3 1 15 2 4 5 1 6 0 0 0 0
# 1

# %%
#check if the given two trees are identical
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []

def isIdentical(tree1, tree2):
    l1=[]
    l2=[]
    def tree1Nodes(tree1, l1):
        l1.append(tree1.data)
        for child in tree1.children:
            tree1Nodes(child, l1)
        return l1
    def tree2Nodes(tree2, l2):
        l2.append(tree2.data)
        for child in tree2.children:
            tree2Nodes(child, l2)
        return l2
    if tree1Nodes(tree1, l1)==tree2Nodes(tree2, l2):
        return True
    return False

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr1 = list(int(x) for x in input().strip().split(' '))
tree1 = createLevelWiseTree(arr1)
arr2 = list(int(x) for x in input().strip().split(' '))
tree2 = createLevelWiseTree(arr2)
if isIdentical(tree1, tree2):
    print('true')
else:
    print('false')
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 10 3 20 30 40 2 40 50 0 0 0 0
# true

# %%
#find the next no greater than n approach 1
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []

def nextLargest(tree, n, l):
    if tree.data>n:
        l.append(tree.data)
    for child in tree.children:
        if child.data>n:
            l.append(child.data)
        nextLargest(child, n, l)
    return l

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
n = int(input())
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
l=[]
print(min(nextLargest(tree, n, l)))
# Out:
# 21
# 10 3 20 30 40 2 40 50 0 0 0 0
# 30

# %%
#find the next no greater than n approach 2
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []

def nextLargest(tree, n):
    if tree.data>n:
        node=tree.data
    else:
        node=None
    for child in tree.children:
        childNode=nextLargest(child, n)
        if childNode:
            if node== None or node>childNode:
                node=childNode
    return node

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
n = int(input())
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
print(nextLargest(tree, n))
# Out:
# 18
# 10 3 20 30 40 2 40 50 0 0 0 0
# 20

# %%
#replace each node with its depth value
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []

def replacewithDepthd(tree, d):
    tree.data=d
    for child in tree.children:
        replacewithDepthd(child,d+1)
        
def replacewithDepth(tree):
    replacewithDepthd(tree, 0)

def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

def printLevelAtNewLine(tree):
    q = [tree]
    newq = []
    while q:
        parent = q.pop(0)
        print(parent.data, end=' ')
        for child in parent.children:
            newq.append(child)
        if len(q)==0:
            q = newq
            newq = []
            print()  # Move to next Line

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
replacewithDepth(tree)
printLevelAtNewLine(tree)
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 0
# 1 1 1
# 2 2
